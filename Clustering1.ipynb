# %% [markdown]
# <a href="https://colab.research.google.com/github/Avishi2511/Clustering/blob/main/Clustering1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.clustering import *
import pandas as pd

myDataSet = pd.read_csv("/forestfires.csv")

results = pd.DataFrame(columns=["Preprocessing", "Number of Clusters", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin"])

num_clusters = [3, 4, 5]

def get_parameters(num_clusters, preprocessing):
    for num in num_clusters:
        model = create_model('kmeans', num_clusters=num)
        prediction = assign_model(model)
        performance = pull()

        results.loc[len(results)] = [
            preprocessing,
            num,
            performance['Silhouette'][0],
            performance['Calinski-Harabasz'][0],
            performance['Davies-Bouldin'][0]
        ]

def run_all():
    print("For no data processing")
    setup(data=myDataSet, verbose=False)
    get_parameters(num_clusters, "No Data Processing")

    print("For using normalization")
    setup(data=myDataSet, normalize=True, normalize_method='zscore', verbose=False)
    get_parameters(num_clusters, "Normalization")

    print("For using transformation")
    setup(data=myDataSet, transformation=True, transformation_method='yeo-johnson', verbose=False)
    get_parameters(num_clusters, "Transformation")

    print("For using PCA")
    setup(data=myDataSet, pca=True, pca_method='linear', verbose=False)
    get_parameters(num_clusters, "PCA")

    print("For using N+T")
    setup(data=myDataSet, normalize=True, normalize_method='zscore', transformation=True,
          transformation_method='yeo-johnson', verbose=False)
    get_parameters(num_clusters, "N+T")

    print("For using N+T+PCA")
    setup(data=myDataSet, normalize=True, normalize_method='zscore', transformation=True,
          transformation_method='yeo-johnson', pca=True, pca_method='linear', verbose=False)
    get_parameters(num_clusters, "N+T+PCA")

run_all()

print("\nClustering Performance Metrics:")
print(results)
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_4a0c6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a0c6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4a0c6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4a0c6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4a0c6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4a0c6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4a0c6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a0c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a0c6_row0_col0" class="data row0 col0" >0.6114</td>
#       <td id="T_4a0c6_row0_col1" class="data row0 col1" >1411.1103</td>
#       <td id="T_4a0c6_row0_col2" class="data row0 col2" >0.5369</td>
#       <td id="T_4a0c6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4a0c6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4a0c6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_6ee9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ee9c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6ee9c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6ee9c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6ee9c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6ee9c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6ee9c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ee9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ee9c_row0_col0" class="data row0 col0" >0.4060</td>
#       <td id="T_6ee9c_row0_col1" class="data row0 col1" >1188.5239</td>
#       <td id="T_6ee9c_row0_col2" class="data row0 col2" >0.9152</td>
#       <td id="T_6ee9c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6ee9c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6ee9c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e3756" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3756_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e3756_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e3756_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e3756_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e3756_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e3756_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3756_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3756_row0_col0" class="data row0 col0" >0.4216</td>
#       <td id="T_e3756_row0_col1" class="data row0 col1" >1465.2729</td>
#       <td id="T_e3756_row0_col2" class="data row0 col2" >0.7494</td>
#       <td id="T_e3756_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e3756_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e3756_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalization
# <style type="text/css">
# </style>
# <table id="T_59f70" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59f70_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_59f70_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_59f70_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_59f70_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_59f70_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_59f70_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59f70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59f70_row0_col0" class="data row0 col0" >0.0952</td>
#       <td id="T_59f70_row0_col1" class="data row0 col1" >49.0502</td>
#       <td id="T_59f70_row0_col2" class="data row0 col2" >2.6590</td>
#       <td id="T_59f70_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_59f70_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_59f70_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_313c7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_313c7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_313c7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_313c7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_313c7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_313c7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_313c7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_313c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_313c7_row0_col0" class="data row0 col0" >0.1102</td>
#       <td id="T_313c7_row0_col1" class="data row0 col1" >43.8582</td>
#       <td id="T_313c7_row0_col2" class="data row0 col2" >2.3241</td>
#       <td id="T_313c7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_313c7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_313c7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7e532" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e532_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7e532_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7e532_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7e532_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7e532_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7e532_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e532_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e532_row0_col0" class="data row0 col0" >0.1215</td>
#       <td id="T_7e532_row0_col1" class="data row0 col1" >40.9151</td>
#       <td id="T_7e532_row0_col2" class="data row0 col2" >2.2781</td>
#       <td id="T_7e532_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7e532_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7e532_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using transformation
# <style type="text/css">
# </style>
# <table id="T_cb689" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb689_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cb689_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cb689_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cb689_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cb689_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cb689_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb689_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb689_row0_col0" class="data row0 col0" >0.6111</td>
#       <td id="T_cb689_row0_col1" class="data row0 col1" >1255.6700</td>
#       <td id="T_cb689_row0_col2" class="data row0 col2" >0.4905</td>
#       <td id="T_cb689_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cb689_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cb689_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_0f86b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f86b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0f86b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0f86b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0f86b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0f86b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0f86b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f86b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f86b_row0_col0" class="data row0 col0" >0.5240</td>
#       <td id="T_0f86b_row0_col1" class="data row0 col1" >1378.3184</td>
#       <td id="T_0f86b_row0_col2" class="data row0 col2" >0.5304</td>
#       <td id="T_0f86b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0f86b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0f86b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a8f38" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f38_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a8f38_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a8f38_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a8f38_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a8f38_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a8f38_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f38_row0_col0" class="data row0 col0" >0.4981</td>
#       <td id="T_a8f38_row0_col1" class="data row0 col1" >1357.8664</td>
#       <td id="T_a8f38_row0_col2" class="data row0 col2" >0.6007</td>
#       <td id="T_a8f38_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a8f38_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a8f38_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using PCA
# <style type="text/css">
# </style>
# <table id="T_30e47" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30e47_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_30e47_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_30e47_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_30e47_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_30e47_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_30e47_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30e47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30e47_row0_col0" class="data row0 col0" >0.6114</td>
#       <td id="T_30e47_row0_col1" class="data row0 col1" >1411.1103</td>
#       <td id="T_30e47_row0_col2" class="data row0 col2" >0.5369</td>
#       <td id="T_30e47_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_30e47_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_30e47_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_fc71e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc71e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc71e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc71e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc71e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc71e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc71e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc71e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc71e_row0_col0" class="data row0 col0" >0.4186</td>
#       <td id="T_fc71e_row0_col1" class="data row0 col1" >1192.4309</td>
#       <td id="T_fc71e_row0_col2" class="data row0 col2" >0.9256</td>
#       <td id="T_fc71e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fc71e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fc71e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_230fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_230fb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_230fb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_230fb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_230fb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_230fb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_230fb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_230fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_230fb_row0_col0" class="data row0 col0" >0.4146</td>
#       <td id="T_230fb_row0_col1" class="data row0 col1" >1471.3503</td>
#       <td id="T_230fb_row0_col2" class="data row0 col2" >0.7507</td>
#       <td id="T_230fb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_230fb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_230fb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T
# <style type="text/css">
# </style>
# <table id="T_304fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_304fc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_304fc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_304fc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_304fc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_304fc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_304fc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_304fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_304fc_row0_col0" class="data row0 col0" >0.0766</td>
#       <td id="T_304fc_row0_col1" class="data row0 col1" >51.5635</td>
#       <td id="T_304fc_row0_col2" class="data row0 col2" >2.6101</td>
#       <td id="T_304fc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_304fc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_304fc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_ea2aa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea2aa_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ea2aa_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ea2aa_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ea2aa_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ea2aa_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ea2aa_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea2aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea2aa_row0_col0" class="data row0 col0" >0.0735</td>
#       <td id="T_ea2aa_row0_col1" class="data row0 col1" >32.6804</td>
#       <td id="T_ea2aa_row0_col2" class="data row0 col2" >2.9507</td>
#       <td id="T_ea2aa_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ea2aa_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ea2aa_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7a401" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a401_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7a401_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7a401_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7a401_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7a401_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7a401_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a401_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a401_row0_col0" class="data row0 col0" >0.1099</td>
#       <td id="T_7a401_row0_col1" class="data row0 col1" >41.2568</td>
#       <td id="T_7a401_row0_col2" class="data row0 col2" >2.2072</td>
#       <td id="T_7a401_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7a401_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7a401_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T+PCA
# <style type="text/css">
# </style>
# <table id="T_966fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_966fc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_966fc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_966fc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_966fc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_966fc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_966fc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_966fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_966fc_row0_col0" class="data row0 col0" >0.0908</td>
#       <td id="T_966fc_row0_col1" class="data row0 col1" >51.4817</td>
#       <td id="T_966fc_row0_col2" class="data row0 col2" >2.6922</td>
#       <td id="T_966fc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_966fc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_966fc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_20a43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20a43_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_20a43_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_20a43_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_20a43_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_20a43_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_20a43_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20a43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20a43_row0_col0" class="data row0 col0" >0.0748</td>
#       <td id="T_20a43_row0_col1" class="data row0 col1" >41.2854</td>
#       <td id="T_20a43_row0_col2" class="data row0 col2" >2.4862</td>
#       <td id="T_20a43_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_20a43_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_20a43_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_46f23" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46f23_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_46f23_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_46f23_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_46f23_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_46f23_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_46f23_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46f23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46f23_row0_col0" class="data row0 col0" >0.0861</td>
#       <td id="T_46f23_row0_col1" class="data row0 col1" >36.2083</td>
#       <td id="T_46f23_row0_col2" class="data row0 col2" >2.3875</td>
#       <td id="T_46f23_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_46f23_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_46f23_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Clustering Performance Metrics:
#          Preprocessing  Number of Clusters  Silhouette  Calinski-Harabasz  \
# 0   No Data Processing                   3      0.6114          1411.1103
# 1   No Data Processing                   4      0.4060          1188.5239
# 2   No Data Processing                   5      0.4216          1465.2729
# 3        Normalization                   3      0.0952            49.0502
# 4        Normalization                   4      0.1102            43.8582
# 5        Normalization                   5      0.1215            40.9151
# 6       Transformation                   3      0.6111          1255.6700
# 7       Transformation                   4      0.5240          1378.3184
# 8       Transformation                   5      0.4981          1357.8664
# 9                  PCA                   3      0.6114          1411.1103
# 10                 PCA                   4      0.4186          1192.4309
# 11                 PCA                   5      0.4146          1471.3503
# 12                 N+T                   3      0.0766            51.5635
# 13                 N+T                   4      0.0735            32.6804
# 14                 N+T                   5      0.1099            41.2568
# 15             N+T+PCA                   3      0.0908            51.4817
# 16             N+T+PCA                   4      0.0748            41.2854
# 17             N+T+PCA                   5      0.0861            36.2083
#
#     Davies-Bouldin
# 0           0.5369
# 1           0.9152
# 2           0.7494
# 3           2.6590
# 4           2.3241
# 5           2.2781
# 6           0.4905
# 7           0.5304
# 8           0.6007
# 9           0.5369
# 10          0.9256
# 11          0.7507
# 12          2.6101
# 13          2.9507
# 14          2.2072
# 15          2.6922
# 16          2.4862
# 17          2.3875

# %%
from pycaret.clustering import *
import pandas as pd

myDataSet = pd.read_csv("/forestfires.csv")

results = pd.DataFrame(columns=["Preprocessing", "Number of Clusters", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin"])

num_clusters = [3, 4, 5]

def get_parameters(num_clusters, preprocessing):
    for num in num_clusters:
        model = create_model('hclust', num_clusters=num)
        prediction = assign_model(model)
        performance = pull()

        results.loc[len(results)] = [
            preprocessing,
            num,
            performance['Silhouette'][0],
            performance['Calinski-Harabasz'][0],
            performance['Davies-Bouldin'][0]
        ]

print("For no data processing")
setup(data=myDataSet, verbose=False)
get_parameters(num_clusters, "No Data Processing")

print("For using normalization")
setup(data=myDataSet, normalize=True, normalize_method='zscore', verbose=False)
get_parameters(num_clusters, "Normalization")

print("For using transformation")
setup(data=myDataSet, transformation=True, transformation_method='yeo-johnson', verbose=False)
get_parameters(num_clusters, "Transformation")

print("For using PCA")
setup(data=myDataSet, pca=True, pca_method='linear', verbose=False)
get_parameters(num_clusters, "PCA")

print("For using N+T")
setup(data=myDataSet, normalize=True, normalize_method='zscore', transformation=True,
      transformation_method='yeo-johnson', verbose=False)
get_parameters(num_clusters, "N+T")

print("For using N+T+PCA")
setup(data=myDataSet, normalize=True, normalize_method='zscore', transformation=True,
      transformation_method='yeo-johnson', pca=True, pca_method='linear', verbose=False)
get_parameters(num_clusters, "N+T+PCA")

print("\nClustering Performance Metrics:")
print(results)
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_937d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_937d1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_937d1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_937d1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_937d1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_937d1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_937d1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_937d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_937d1_row0_col0" class="data row0 col0" >0.6281</td>
#       <td id="T_937d1_row0_col1" class="data row0 col1" >1377.0471</td>
#       <td id="T_937d1_row0_col2" class="data row0 col2" >0.5108</td>
#       <td id="T_937d1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_937d1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_937d1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_3704b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3704b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3704b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3704b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3704b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3704b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3704b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3704b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3704b_row0_col0" class="data row0 col0" >0.6397</td>
#       <td id="T_3704b_row0_col1" class="data row0 col1" >1358.4250</td>
#       <td id="T_3704b_row0_col2" class="data row0 col2" >0.4474</td>
#       <td id="T_3704b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3704b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3704b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_b5d5d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5d5d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b5d5d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b5d5d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b5d5d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b5d5d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b5d5d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5d5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5d5d_row0_col0" class="data row0 col0" >0.4111</td>
#       <td id="T_b5d5d_row0_col1" class="data row0 col1" >1310.0411</td>
#       <td id="T_b5d5d_row0_col2" class="data row0 col2" >0.7070</td>
#       <td id="T_b5d5d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b5d5d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b5d5d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalization
# <style type="text/css">
# </style>
# <table id="T_27bf5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27bf5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_27bf5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_27bf5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_27bf5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_27bf5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_27bf5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27bf5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27bf5_row0_col0" class="data row0 col0" >0.1885</td>
#       <td id="T_27bf5_row0_col1" class="data row0 col1" >43.6191</td>
#       <td id="T_27bf5_row0_col2" class="data row0 col2" >2.6355</td>
#       <td id="T_27bf5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_27bf5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_27bf5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_90d63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90d63_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90d63_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90d63_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90d63_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90d63_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90d63_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90d63_row0_col0" class="data row0 col0" >0.1955</td>
#       <td id="T_90d63_row0_col1" class="data row0 col1" >39.1196</td>
#       <td id="T_90d63_row0_col2" class="data row0 col2" >2.1279</td>
#       <td id="T_90d63_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_90d63_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_90d63_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_d8900" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8900_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d8900_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d8900_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d8900_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d8900_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d8900_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8900_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8900_row0_col0" class="data row0 col0" >0.1763</td>
#       <td id="T_d8900_row0_col1" class="data row0 col1" >37.2473</td>
#       <td id="T_d8900_row0_col2" class="data row0 col2" >2.1058</td>
#       <td id="T_d8900_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d8900_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d8900_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using transformation
# <style type="text/css">
# </style>
# <table id="T_4b004" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b004_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4b004_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4b004_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4b004_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4b004_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4b004_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b004_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b004_row0_col0" class="data row0 col0" >0.5958</td>
#       <td id="T_4b004_row0_col1" class="data row0 col1" >1219.5697</td>
#       <td id="T_4b004_row0_col2" class="data row0 col2" >0.5230</td>
#       <td id="T_4b004_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4b004_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4b004_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_eef83" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eef83_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_eef83_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_eef83_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_eef83_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_eef83_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_eef83_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eef83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eef83_row0_col0" class="data row0 col0" >0.5412</td>
#       <td id="T_eef83_row0_col1" class="data row0 col1" >1263.9338</td>
#       <td id="T_eef83_row0_col2" class="data row0 col2" >0.4735</td>
#       <td id="T_eef83_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_eef83_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_eef83_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_712a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_712a0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_712a0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_712a0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_712a0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_712a0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_712a0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_712a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_712a0_row0_col0" class="data row0 col0" >0.5081</td>
#       <td id="T_712a0_row0_col1" class="data row0 col1" >1380.6420</td>
#       <td id="T_712a0_row0_col2" class="data row0 col2" >0.4804</td>
#       <td id="T_712a0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_712a0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_712a0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using PCA
# <style type="text/css">
# </style>
# <table id="T_639d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_639d1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_639d1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_639d1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_639d1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_639d1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_639d1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_639d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_639d1_row0_col0" class="data row0 col0" >0.6281</td>
#       <td id="T_639d1_row0_col1" class="data row0 col1" >1377.0471</td>
#       <td id="T_639d1_row0_col2" class="data row0 col2" >0.5108</td>
#       <td id="T_639d1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_639d1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_639d1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_77c66" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77c66_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_77c66_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_77c66_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_77c66_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_77c66_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_77c66_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77c66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77c66_row0_col0" class="data row0 col0" >0.6397</td>
#       <td id="T_77c66_row0_col1" class="data row0 col1" >1358.4250</td>
#       <td id="T_77c66_row0_col2" class="data row0 col2" >0.4474</td>
#       <td id="T_77c66_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_77c66_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_77c66_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_ad25b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad25b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ad25b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ad25b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ad25b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ad25b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ad25b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad25b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad25b_row0_col0" class="data row0 col0" >0.4111</td>
#       <td id="T_ad25b_row0_col1" class="data row0 col1" >1310.0411</td>
#       <td id="T_ad25b_row0_col2" class="data row0 col2" >0.7070</td>
#       <td id="T_ad25b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ad25b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ad25b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T
# <style type="text/css">
# </style>
# <table id="T_a3fe7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3fe7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a3fe7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a3fe7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a3fe7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a3fe7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a3fe7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3fe7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3fe7_row0_col0" class="data row0 col0" >0.1821</td>
#       <td id="T_a3fe7_row0_col1" class="data row0 col1" >45.9176</td>
#       <td id="T_a3fe7_row0_col2" class="data row0 col2" >2.6532</td>
#       <td id="T_a3fe7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a3fe7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a3fe7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_db3d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db3d1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_db3d1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_db3d1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_db3d1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_db3d1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_db3d1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db3d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db3d1_row0_col0" class="data row0 col0" >0.1661</td>
#       <td id="T_db3d1_row0_col1" class="data row0 col1" >40.8784</td>
#       <td id="T_db3d1_row0_col2" class="data row0 col2" >2.4859</td>
#       <td id="T_db3d1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_db3d1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_db3d1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_423bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_423bc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_423bc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_423bc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_423bc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_423bc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_423bc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_423bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_423bc_row0_col0" class="data row0 col0" >0.1799</td>
#       <td id="T_423bc_row0_col1" class="data row0 col1" >38.5525</td>
#       <td id="T_423bc_row0_col2" class="data row0 col2" >2.1450</td>
#       <td id="T_423bc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_423bc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_423bc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T+PCA
# <style type="text/css">
# </style>
# <table id="T_7d688" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d688_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7d688_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7d688_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7d688_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7d688_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7d688_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d688_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d688_row0_col0" class="data row0 col0" >0.1821</td>
#       <td id="T_7d688_row0_col1" class="data row0 col1" >45.9176</td>
#       <td id="T_7d688_row0_col2" class="data row0 col2" >2.6532</td>
#       <td id="T_7d688_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7d688_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7d688_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_12099" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12099_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_12099_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_12099_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_12099_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_12099_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_12099_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12099_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12099_row0_col0" class="data row0 col0" >0.1661</td>
#       <td id="T_12099_row0_col1" class="data row0 col1" >40.8784</td>
#       <td id="T_12099_row0_col2" class="data row0 col2" >2.4859</td>
#       <td id="T_12099_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_12099_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_12099_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_530dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_530dd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_530dd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_530dd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_530dd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_530dd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_530dd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_530dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_530dd_row0_col0" class="data row0 col0" >0.1799</td>
#       <td id="T_530dd_row0_col1" class="data row0 col1" >38.5525</td>
#       <td id="T_530dd_row0_col2" class="data row0 col2" >2.1450</td>
#       <td id="T_530dd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_530dd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_530dd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Clustering Performance Metrics:
#          Preprocessing  Number of Clusters  Silhouette  Calinski-Harabasz  \
# 0   No Data Processing                   3      0.6281          1377.0471
# 1   No Data Processing                   4      0.6397          1358.4250
# 2   No Data Processing                   5      0.4111          1310.0411
# 3        Normalization                   3      0.1885            43.6191
# 4        Normalization                   4      0.1955            39.1196
# 5        Normalization                   5      0.1763            37.2473
# 6       Transformation                   3      0.5958          1219.5697
# 7       Transformation                   4      0.5412          1263.9338
# 8       Transformation                   5      0.5081          1380.6420
# 9                  PCA                   3      0.6281          1377.0471
# 10                 PCA                   4      0.6397          1358.4250
# 11                 PCA                   5      0.4111          1310.0411
# 12                 N+T                   3      0.1821            45.9176
# 13                 N+T                   4      0.1661            40.8784
# 14                 N+T                   5      0.1799            38.5525
# 15             N+T+PCA                   3      0.1821            45.9176
# 16             N+T+PCA                   4      0.1661            40.8784
# 17             N+T+PCA                   5      0.1799            38.5525
#
#     Davies-Bouldin
# 0           0.5108
# 1           0.4474
# 2           0.7070
# 3           2.6355
# 4           2.1279
# 5           2.1058
# 6           0.5230
# 7           0.4735
# 8           0.4804
# 9           0.5108
# 10          0.4474
# 11          0.7070
# 12          2.6532
# 13          2.4859
# 14          2.1450
# 15          2.6532
# 16          2.4859
# 17          2.1450

# %%
from pycaret.clustering import *
import pandas as pd

myDataSet = pd.read_csv("/forestfires.csv")

results = pd.DataFrame(columns=["Preprocessing", "Number of Clusters", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin"])

num_clusters = [3, 4, 5]

def get_parameters(num_clusters, preprocessing):
    for num in num_clusters:
        model = create_model('meanshift', num_clusters=num)
        prediction = assign_model(model)
        performance = pull()

        results.loc[len(results)] = [
            preprocessing,
            num,
            performance['Silhouette'][0],
            performance['Calinski-Harabasz'][0],
            performance['Davies-Bouldin'][0]
        ]

print("For no data processing")
kMeanClusteringParameters = setup(data=myDataSet, verbose=False)
get_parameters(num_clusters, "No Data Processing")

print("For using normalization")
normparam = setup(data=myDataSet, normalize=True, normalize_method='zscore', verbose=False)
get_parameters(num_clusters, "Normalization")

print("For using transformation")
transformparam = setup(data=myDataSet, transformation=True, transformation_method='yeo-johnson', verbose=False)
get_parameters(num_clusters, "Transformation")

print("For using PCA")
pcaparam = setup(data=myDataSet, pca=True, pca_method='linear', verbose=False)
get_parameters(num_clusters, "PCA")

print("For using N+T")
ntparam = setup(data=myDataSet, transformation=True, normalize=True, normalize_method='zscore',
                transformation_method='yeo-johnson', verbose=False)
get_parameters(num_clusters, "N+T")

print("For using N+T+PCA")
ntpcaparam = setup(data=myDataSet, transformation=True, normalize=True, pca=True,
                   normalize_method='zscore', transformation_method='yeo-johnson',
                   pca_method='linear', verbose=False)
get_parameters(num_clusters, "N+T+PCA")

print("\nClustering Performance Metrics:")
print(results)
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_00b16" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00b16_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_00b16_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_00b16_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_00b16_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_00b16_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_00b16_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00b16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00b16_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_00b16_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_00b16_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_00b16_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_00b16_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_00b16_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e1186" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1186_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e1186_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e1186_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e1186_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e1186_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e1186_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1186_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1186_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_e1186_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_e1186_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_e1186_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e1186_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e1186_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_d45cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d45cd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d45cd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d45cd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d45cd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d45cd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d45cd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d45cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d45cd_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_d45cd_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_d45cd_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_d45cd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d45cd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d45cd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalization
# <style type="text/css">
# </style>
# <table id="T_b4379" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4379_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b4379_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b4379_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b4379_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b4379_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b4379_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4379_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4379_row0_col0" class="data row0 col0" >0.2732</td>
#       <td id="T_b4379_row0_col1" class="data row0 col1" >23.2221</td>
#       <td id="T_b4379_row0_col2" class="data row0 col2" >0.6088</td>
#       <td id="T_b4379_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b4379_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b4379_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a265d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a265d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a265d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a265d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a265d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a265d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a265d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a265d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a265d_row0_col0" class="data row0 col0" >0.2732</td>
#       <td id="T_a265d_row0_col1" class="data row0 col1" >23.2221</td>
#       <td id="T_a265d_row0_col2" class="data row0 col2" >0.6088</td>
#       <td id="T_a265d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a265d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a265d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_879af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_879af_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_879af_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_879af_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_879af_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_879af_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_879af_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_879af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_879af_row0_col0" class="data row0 col0" >0.2732</td>
#       <td id="T_879af_row0_col1" class="data row0 col1" >23.2221</td>
#       <td id="T_879af_row0_col2" class="data row0 col2" >0.6088</td>
#       <td id="T_879af_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_879af_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_879af_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using transformation
# <style type="text/css">
# </style>
# <table id="T_184a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_184a4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_184a4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_184a4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_184a4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_184a4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_184a4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_184a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_184a4_row0_col0" class="data row0 col0" >0.5811</td>
#       <td id="T_184a4_row0_col1" class="data row0 col1" >652.7285</td>
#       <td id="T_184a4_row0_col2" class="data row0 col2" >0.5559</td>
#       <td id="T_184a4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_184a4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_184a4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_45a5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45a5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_45a5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_45a5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_45a5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_45a5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_45a5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45a5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45a5a_row0_col0" class="data row0 col0" >0.5811</td>
#       <td id="T_45a5a_row0_col1" class="data row0 col1" >652.7285</td>
#       <td id="T_45a5a_row0_col2" class="data row0 col2" >0.5559</td>
#       <td id="T_45a5a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_45a5a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_45a5a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_866e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_866e2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_866e2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_866e2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_866e2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_866e2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_866e2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_866e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_866e2_row0_col0" class="data row0 col0" >0.5811</td>
#       <td id="T_866e2_row0_col1" class="data row0 col1" >652.7285</td>
#       <td id="T_866e2_row0_col2" class="data row0 col2" >0.5559</td>
#       <td id="T_866e2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_866e2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_866e2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using PCA
# <style type="text/css">
# </style>
# <table id="T_a40f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a40f9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a40f9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a40f9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a40f9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a40f9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a40f9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a40f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a40f9_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_a40f9_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_a40f9_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_a40f9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a40f9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a40f9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_20382" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20382_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_20382_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_20382_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_20382_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_20382_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_20382_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20382_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20382_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_20382_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_20382_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_20382_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_20382_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_20382_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_23cb0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23cb0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_23cb0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_23cb0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_23cb0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_23cb0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_23cb0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23cb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23cb0_row0_col0" class="data row0 col0" >0.5152</td>
#       <td id="T_23cb0_row0_col1" class="data row0 col1" >627.2620</td>
#       <td id="T_23cb0_row0_col2" class="data row0 col2" >0.4900</td>
#       <td id="T_23cb0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_23cb0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_23cb0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T
# <style type="text/css">
# </style>
# <table id="T_bfdf3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfdf3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bfdf3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bfdf3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bfdf3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bfdf3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bfdf3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfdf3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfdf3_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_bfdf3_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_bfdf3_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_bfdf3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bfdf3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bfdf3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_4c3b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c3b8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4c3b8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4c3b8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4c3b8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4c3b8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4c3b8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c3b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c3b8_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_4c3b8_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_4c3b8_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_4c3b8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4c3b8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4c3b8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a5e9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5e9f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5e9f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5e9f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5e9f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5e9f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5e9f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5e9f_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_a5e9f_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_a5e9f_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_a5e9f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a5e9f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a5e9f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T+PCA
# <style type="text/css">
# </style>
# <table id="T_b392e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b392e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b392e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b392e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b392e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b392e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b392e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b392e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b392e_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_b392e_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_b392e_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_b392e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b392e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b392e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_10ddd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10ddd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_10ddd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_10ddd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_10ddd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_10ddd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_10ddd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10ddd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10ddd_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_10ddd_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_10ddd_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_10ddd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_10ddd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_10ddd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_22c0c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22c0c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_22c0c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_22c0c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_22c0c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_22c0c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_22c0c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22c0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22c0c_row0_col0" class="data row0 col0" >0.2980</td>
#       <td id="T_22c0c_row0_col1" class="data row0 col1" >30.0850</td>
#       <td id="T_22c0c_row0_col2" class="data row0 col2" >0.7733</td>
#       <td id="T_22c0c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_22c0c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_22c0c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Clustering Performance Metrics:
#          Preprocessing  Number of Clusters  Silhouette  Calinski-Harabasz  \
# 0   No Data Processing                   3      0.5152           627.2620
# 1   No Data Processing                   4      0.5152           627.2620
# 2   No Data Processing                   5      0.5152           627.2620
# 3        Normalization                   3      0.2732            23.2221
# 4        Normalization                   4      0.2732            23.2221
# 5        Normalization                   5      0.2732            23.2221
# 6       Transformation                   3      0.5811           652.7285
# 7       Transformation                   4      0.5811           652.7285
# 8       Transformation                   5      0.5811           652.7285
# 9                  PCA                   3      0.5152           627.2620
# 10                 PCA                   4      0.5152           627.2620
# 11                 PCA                   5      0.5152           627.2620
# 12                 N+T                   3      0.2980            30.0850
# 13                 N+T                   4      0.2980            30.0850
# 14                 N+T                   5      0.2980            30.0850
# 15             N+T+PCA                   3      0.2980            30.0850
# 16             N+T+PCA                   4      0.2980            30.0850
# 17             N+T+PCA                   5      0.2980            30.0850
#
#     Davies-Bouldin
# 0           0.4900
# 1           0.4900
# 2           0.4900
# 3           0.6088
# 4           0.6088
# 5           0.6088
# 6           0.5559
# 7           0.5559
# 8           0.5559
# 9           0.4900
# 10          0.4900
# 11          0.4900
# 12          0.7733
# 13          0.7733
# 14          0.7733
# 15          0.7733
# 16          0.7733
# 17          0.7733

# %%
t_kmeans=setup(data=myDataSet,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
KMeanModel = create_model('kmeans', num_clusters=4)
evaluate_model(KMeanModel)
plot_model(KMeanModel, plot='cluster')
# Out:
# <style type="text/css">
# </style>
# <table id="T_481ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_481ef_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_481ef_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_481ef_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_481ef_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_481ef_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_481ef_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_481ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_481ef_row0_col0" class="data row0 col0" >0.5451</td>
#       <td id="T_481ef_row0_col1" class="data row0 col1" >1327.4688</td>
#       <td id="T_481ef_row0_col2" class="data row0 col2" >0.5313</td>
#       <td id="T_481ef_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_481ef_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_481ef_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9975abe2-0184-419d-a3b0-ea9b96105a0b" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("